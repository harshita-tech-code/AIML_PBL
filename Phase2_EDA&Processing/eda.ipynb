# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/data_train.csv")

# %%
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/data_train.csv")
    return df  # Add this line
# --- 1. Missing Value Handling ---
# Identify and impute missing values to ensure the pipeline doesn't break
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/data_train.csv")
    
    # --- 1. Missing Value Handling ---
    # Identify and impute missing values to ensure the pipeline doesn't break
    if df.isnull().sum().sum() > 0:
        print("Missing values detected. Handling via median imputation...")
        imputer = SimpleImputer(strategy='median')
        df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
    else:
        print("Dataset integrity verified: No missing values detected.")
    
    return df  # Add this line

# %%
# --- 2. Data Cleaning & Transformation ---
if __name__ == "__main__":
    df = pd.read_csv("../Phase1_DataCollection/data/data_train.csv", sep=';')
    df["age"] = df["age"] / 365  
# Convert days to years
df["age"] = df["age"] / 365

# %%
# --- 3. Statistical Analysis ---
print("\n--- Descriptive Statistics ---")
print(df.describe())
# Out:
# --- Descriptive Statistics ---
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900      0.146135      1.349571    164.359229     74.205690
# std    28851.302323      0.018519      0.476838      8.210126     14.395757
# min        0.000000      0.081051      1.000000     55.000000     10.000000
# 25%    25006.750000      0.132588      1.000000    159.000000     65.000000
# 50%    50001.500000      0.147893      1.000000    165.000000     72.000000
# 75%    74889.250000      0.160083      2.000000    170.000000     82.000000
# max    99999.000000      0.177992      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
# --- 4. Visualization ---
sns.set_theme(style="whitegrid")

# %%
# Target distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='cardio', data=df)
plt.title('Distribution of Target (Cardio)')
plt.show()

# %%
# Age vs Disease relationship
plt.figure(figsize=(8, 4))
sns.histplot(data=df, x='age', hue='cardio', kde=True, element="step")
plt.title('Age Distribution by Cardio Status')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
if __name__ == "__main__":
    if __name__ == "__main__":
        df = pd.read_csv("../Phase1_DataCollection/data/data_train.csv", sep=';')
